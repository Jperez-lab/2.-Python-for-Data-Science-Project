# %%
import urllib.request

# %%
import sys
# !{sys.executable} -m pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\lenovo\anaconda3\envs\jcpt\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lenovo\anaconda3\envs\jcpt\lib\site-packages (from beautifulsoup4) (2.3.2.post1)

# %%
from bs4 import BeautifulSoup
import requests

# %%
# !{sys.executable} -m pip install html5lib==1.1
# Out:
# Requirement already satisfied: html5lib==1.1 in c:\users\lenovo\anaconda3\envs\jcpt\lib\site-packages (1.1)
# Requirement already satisfied: webencodings in c:\users\lenovo\anaconda3\envs\jcpt\lib\site-packages (from html5lib==1.1) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\lenovo\anaconda3\envs\jcpt\lib\site-packages (from html5lib==1.1) (1.15.0)

# %%
url = "http://meteorologia.aerocivil.gov.co/obs_map"

# %%
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html.parser")

# %%
tables = soup.find('table')
tables
# Out:
# <table class="sortable">
# <tr>
# <th class="sortfirstasc">Estación</th>
# <th class="sortfirstasc">Estado Operativo de Aeropuertos</th>
# <th>Hora </th>
# <th>Observaciones </th>
# <th>Temperatura </th>
# <th>RH % </th>
# <th>Viento kt</th>
# <th>Presión in Hg</th>
# <th>Vis km</th>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKPD" onmouseout="UnTip()" onmouseover="Tip('SKPD 101200Z VRB02KT 5000 -SHRA SCT006 OVC020 22/22 Q1014 RMK A2997 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Puerto Inírida / Cesar Gaviria Trujillo</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Chubascos Ligeros
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   22.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   100.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                    4
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.97
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 5
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKAR" onmouseout="UnTip()" onmouseover="Tip('SKAR 101200Z 00000KT 9999 BKN018 20/19 Q1021 RMK A3015 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Armenia / El Edén</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1255 - 1910 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Mayormente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   20.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   93.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   CALMA
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   30.06
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKAS" onmouseout="UnTip()" onmouseover="Tip('SKAS 101200Z 31004KT 9999 VCSH SCT003 BKN050 21/21 Q1015 RMK VCSH/NW/W A2998 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Puerto Asís / Tres de Mayo</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1655 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Chubascos adyacente
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   21.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   100.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   NW 7
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.97
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKBG" onmouseout="UnTip()" onmouseover="Tip('SKBG 101200Z VRB02KT 9999 SCT012 BKN270 21/17 Q1018 RMK A3007 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Bucaramanga / Palonegro</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1155 - 2210 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Mayormente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   21.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   77.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                    4
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.98
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKBO" onmouseout="UnTip()" onmouseover="Tip('SKBO 101200Z VRB02KT 9999 BKN020 12/10 Q1029 NOSIG RMK A3039 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Bogotá / El Dorado</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip('',WIDTH,200,
#          BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#              </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Mayormente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   12.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   87.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                    4
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   30.19
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKBQ" onmouseout="UnTip()" onmouseover="Tip('SKBQ 101200Z VRB02KT 9000 NSC 26/25 Q1011 NOSIG RMK HZ A2987 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Barranquilla / Ernesto Cortissoz</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip('',WIDTH,200,
#          BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#              </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Neblina
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   26.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   94.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                    4
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.87
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 9
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKBU" onmouseout="UnTip()" onmouseover="Tip('SKBU 101200Z 25003KT 1000 +RA OVC008 23/23 Q1014 RMK  A2995 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Buenaventura / Gerardo Tobar López</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1255 - 1910 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   23.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   100.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   WSW 7
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.95
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 1
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKCC" onmouseout="UnTip()" onmouseover="Tip('SKCC 101200Z 20010KT 9999 FEW020 BKN200 27/18 Q1015 RMK A2998 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Cucuta / Camilo Daza</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Mayormente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   27.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   57.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   SSW 18
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.96
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKCG" onmouseout="UnTip()" onmouseover="Tip('SKCG 101200Z 19004KT 8000 VCFG FEW013 BKN200 28/27 Q1010 RMK HZ A2985 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Cartagena / Rafael Núñez</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Niebla Cercana
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   28.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   94.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   S 7
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.85
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 8
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKCL" onmouseout="UnTip()" onmouseover="Tip('SKCL 101200Z 00000KT 8000 VCFG BKN030 21/20 Q1018 NOSIG RMK A3007 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Cali / Alfonso Bonilla Aragón</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip('',WIDTH,200,
#          BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#              </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Niebla Cercana
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   21.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   94.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   CALMA
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   30.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 8
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKEJ" onmouseout="UnTip()" onmouseover="Tip('SKEJ 101200Z 16005KT 9999 SCT020 26/23 Q1012 RMK A2989 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Barrancabermeja / Yariguies</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1355 - 2010 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Parcialmente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   26.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   83.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   SSE 11
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.89
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKIB" onmouseout="UnTip()" onmouseover="Tip('SKIB 101200Z 28004KT 9999 SCT030 22/18 Q1020 RMK A3013 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Ibague / Perales</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1655 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Parcialmente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   22.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   78.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   W 7
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   30.06
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKIP" onmouseout="UnTip()" onmouseover="Tip('SKIP 101200Z 00000KT 9999 3000S BCFG SCT007 BKN070 09/08 Q1030 RMK A3044 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Ipiales / San Luis</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1255 - 1910 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Niebla Irregular
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   9.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   93.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   CALMA
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   30.21
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 3
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKLC" onmouseout="UnTip()" onmouseover="Tip('SKLC 101200Z 14005KT 9999 SCT003 BKN090 25/24 Q1012 RMK A2990 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Carepa / Los Cedros</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Mayormente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   25.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   94.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   SE 11
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.9
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKLT" onmouseout="UnTip()" onmouseover="Tip('SKLT 101200Z 00000KT 8000 -RA BKN012 BKN080 23/23 Q1015 RMK A2997 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Leticia / Alfredo Vásquez Cobo</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 0310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Mayormente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   23.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   100.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   CALMA
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.97
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 8
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKMD" onmouseout="UnTip()" onmouseover="Tip('SKMD 101200Z 36004KT 9000 SCT020 SCT100 20/18 Q1022 RMK HZ A3020 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Medellín / Olaya Herrera</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Neblina
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   20.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   88.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   N 7
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   30.07
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 9
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKMR" onmouseout="UnTip()" onmouseover="Tip('SKMR 101200Z 15004KT 110V170 9999 FEW020 OVC090 24/24 Q1011 REDZ A2988 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Montería / Los Garzones</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   24.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   100.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   SSE 7
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.88
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKMU" onmouseout="UnTip()" onmouseover="Tip('SKMU 101200Z 00000KT 4000 -SHRA FEW003 SCT007 SCT020 23/22 Q1014 RMK A2996 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Mitú / Fabio Alberto León Bentley</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Chubascos Ligeros
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   23.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   94.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   CALMA
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.95
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 4
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKNV" onmouseout="UnTip()" onmouseover="Tip('SKNV 101200Z VRB02KT 9999 VCSH FEW040 BKN100 24/20 Q1015 RMK/VCSH/W A2998 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Neiva / Benito Salas</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Chubascos adyacente
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   24.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   78.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                    4
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.95
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKPC" onmouseout="UnTip()" onmouseover="Tip('SKPC 101200Z VRB02KT 9999 SCT015 25/24 Q1013 RMK A2994 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Puerto Carreño / Germán Olano</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Parcialmente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   25.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   94.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                    4
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.94
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKPE" onmouseout="UnTip()" onmouseover="Tip('SKPE 101200Z 12004KT 9999 VCSH SCT017 SCT080 20/18 Q1020 RMK VCSH/N A3012 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Pereira / Matecaña</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1255 - 1910 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Chubascos adyacente
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   20.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   88.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   ESE 7
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   30.01
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKPP" onmouseout="UnTip()" onmouseover="Tip('SKPP 101200Z 00000KT 9999 SCT040 16/14 Q1022 RMK A3018 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Popayán / Guillermo León Valencia</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1255 - 1910 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Parcialmente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   16.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   87.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   CALMA
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   30.06
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKPS" onmouseout="UnTip()" onmouseover="Tip('SKPS 101200Z 00000KT 9999 3000N BCFG SCT023 14/14 Q1022 RMK A3019 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Pasto / Antonio Nariño</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1255 - 1910 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Niebla Irregular
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   14.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   100.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   CALMA
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   30.07
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 3
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKPV" onmouseout="UnTip()" onmouseover="Tip('SKPV 101200Z 04010KT 9999 SCT017 OVC200 27/25 Q1014 RMK A2994 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Providencia Isla / El Embrujo</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1155 - 1810 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   27.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   88.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   NE 18
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.94
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKRG" onmouseout="UnTip()" onmouseover="Tip('SKRG 101200Z 28003KT 4000 BR BKN007 SCT080 15/14 Q1027 BECMG FM1330 9999 NSW SCT012 RMK A3034 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Rionegro / José Maria Córdova</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip('',WIDTH,200,
#          BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#              </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   15.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   93.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   W 7
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   30.15
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 4
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKRH" onmouseout="UnTip()" onmouseover="Tip('SKRH 101200Z 11012KT 9999 FEW018 29/23 Q1012 RMK A2991 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Riohacha / Almirante Padilla</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1355 - 2010 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Mayormente Despejado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   70.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   ESE 22
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.91
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKSJ" onmouseout="UnTip()" onmouseover="Tip('SKSJ NIL = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">San Jose Del Guaviare / Jorge González</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               11:58
#
#
#        </td>
# <td>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKSM" onmouseout="UnTip()" onmouseover="Tip('SKSM 101200Z VRB02KT 9999 FEW020 BKN200 27/23 Q1012 RMK A2991 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Santa Marta / Simón Bolívar</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1355 - 2010 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Mayormente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   27.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   78.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                    4
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.91
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKSP" onmouseout="UnTip()" onmouseover="Tip('SKSP 101200Z 07011KT 050V110 9999 FEW014 SCT080 28/25 Q1013 RERA RMK A2991 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">San Andrés Isla / Gustavo Rojas Pinilla</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip('',WIDTH,200,
#          BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#              </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Parcialmente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   28.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   83.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   ENE 22
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.91
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKUC" onmouseout="UnTip()" onmouseover="Tip('SKUC 101200Z IDEAM NIL = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Arauca / Santiago Pérez</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1155 - 2210 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Chubascos adyacente
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   25.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   94.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   CALMA
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.97
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 8
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKUI" onmouseout="UnTip()" onmouseover="Tip('SKUI 101200Z 00000KT 5000 -TSRA FEW010CB BKN012 OVC080 23/23 Q1013 RMK CB N A2993 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Quibdó / El Caraño</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Tormenta eléctrica
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   23.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   100.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   CALMA
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.93
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 5
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKVP" onmouseout="UnTip()" onmouseover="Tip('SKVP 101200Z 04007KT 9999 FEW020 SCT070 27/22 Q1014 RMK A2996 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Valledupar / Alfonso Lopez Pumarejo</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1355 - 2010 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Parcialmente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   27.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   74.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   NE 14
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.95
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKVV" onmouseout="UnTip()" onmouseover="Tip('SKVV 101200Z 33004KT 9999 SCT017 BKN090 22/21 Q1011 RERA RMK A3005 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Villavicencio / Vanguardia</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Mayormente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   22.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   94.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   NNW 7
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   30.03
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKCO" onmouseout="UnTip()" onmouseover="Tip('SKCO 101200Z 24005KT 9999 BKN030 24/22 Q1013 RMK A2993 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Tumaco / La Florida</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1255 - 1910 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Mayormente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   24.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   88.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   WSW 11
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.93
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKBS" onmouseout="UnTip()" onmouseover="Tip('SKBS 101200Z 00000KT 9999 BKN025 OVC050 24/24 Q1013 RMK A2991 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Bahia Solano / José Celestino Mutis</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1155 - 2210 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   24.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   100.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   CALMA
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.91
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKGO" onmouseout="UnTip()" onmouseover="Tip('SKGO 101200Z AUTO 30003KT 270V330 9999 FEW032 SCT037 BKN054 21/20 Q1017 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Cartago / Santa Ana</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1255 - 1910 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Mayormente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   21.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   94.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   WNW 7
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.97
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKCZ" onmouseout="UnTip()" onmouseover="Tip('SKCZ 101200Z 22003KT 9999 SCT045 24/22 Q1011 RMK A2988 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Corozal / Las Brujas</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1355 - 2010 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Parcialmente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   24.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   88.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   SW 7
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.88
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKFL" onmouseout="UnTip()" onmouseover="Tip('SKFL NIL = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Florencia / Gustavo Artunduaga Paredes</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1255 - 1910 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               11:58
#
#
#        </td>
# <td>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKGI" onmouseout="UnTip()" onmouseover="Tip('SKGI NIL = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Girardot / Santiago Vila</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1255 - 1910 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               11:58
#
#
#        </td>
# <td>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKGP" onmouseout="UnTip()" onmouseover="Tip('SKGP 101200Z /////KT 5000 MIFG OVC020 XX/XX Q//// = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Guapi / Juan Casiano</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 1710 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Niebla
#
#
#        </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
#                 5
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKGY" onmouseout="UnTip()" onmouseover="Tip('SKGY 101200Z 04004KT 350V090 9000 SCT030 12/12 Q1029 RMK A3039 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Guaymaral / Flaminio Suárez</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Parcialmente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   12.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   100.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   NE 7
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   30.19
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 9
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKMZ" onmouseout="UnTip()" onmouseover="Tip('SKMZ 101200Z VRB02KT 8000 VCFG BKN040 15/14 Q1028 RMK VCFG/W  A3036 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Manizales / La Nubia</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1255 - 1910 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Niebla Cercana
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   15.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   93.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                    4
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   30.2
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 8
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKQU" onmouseout="UnTip()" onmouseover="Tip('SKQU 101200Z VRB02KT 8000 BKN030 BKN060 23/21 Q1014 RMK VCFG/E A2994 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Mariquita / Jose Celestino Mutis</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1300 - 1910 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Mayormente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   23.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   88.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                    4
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.91
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 8
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKSV" onmouseout="UnTip()" onmouseover="Tip('SKSV NIL = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">San Vicente del Caguan / Eduardo Solano</a>
# </td>
# <td align="center">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         --
#       </td>
# <td>
#
#
#               11:58
#
#
#        </td>
# <td>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKSA" onmouseout="UnTip()" onmouseover="Tip('SKSA 101200Z VRB02KT 9999 NSC 25/21 Q1015 RMK A2997 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Saravena / Los Colonizadores</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1255 - 2110 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Despejado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   25.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   78.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                    4
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.96
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKTM" onmouseout="UnTip()" onmouseover="Tip('SKTM NIL = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Tame / Gabriel Vargas Santos</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1255 - 1910 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               11:58
#
#
#        </td>
# <td>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# <div style="color:#000000">
# </div>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/meteogram/index?icao=SKYP" onmouseout="UnTip()" onmouseover="Tip('SKYP 101200Z 33004KT 300V360 9999 SCT015 SCT030 23/22 Q1016 REDZ RMK A3000 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Yopal / El Alcaraván</a>
# </td>
# <td align="center">
# <a class="airport_status_rules" href="" onmouseout="UnTip()" onmouseover="Tip(' 1055 - 2310 UTC',WIDTH,200,
#            BGCOLOR, '', CENTERMOUSE, true, FONTSIZE,'9pt');" style="background-color:;" target="NEW">
#                </a>
# </td>
# <td>
#
#
#               12:00
#
#
#        </td>
# <td>
#
#
#             Parcialmente Nublado
#
#
#        </td>
# <td>
# <div style="color:#000000">
#
#
#                   23.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   94.0
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
# <!-- Need method to show formatted wind dir speed gust -->
#                   NNW 7
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#
#
#                   29.99
#
#
#             </div>
# </td>
# <td>
# <div style="color:#000000">
#                 10
#              </div>
# </td>
# </tr>
# </table>

# %%
len(tables)
# Out:
# 97

# %%
tag_object=soup.a
tag_object
# Out:
# <a href="/user_alerts" id="user_alert_link">You have 0 alerts to review!</a>

# %%
list_input=tables.find_all(href="/meteogram/index?icao=SKBO")
list_input
# Out:
# [<a href="/meteogram/index?icao=SKBO" onmouseout="UnTip()" onmouseover="Tip('SKBO 031100Z 05007KT 9999 FEW017 SCT200 09/07 Q1028 NOSIG RMK A3036 = ',WIDTH,400, BGCOLOR, '#FFFFFF', CENTERMOUSE, true, FONTSIZE,'9pt');" target="NEW">Bogotá / El Dorado</a>]

# %%
sa=list_input.split(" ")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [65], in <module>
# ----> 1 sa=list_input.split(" ")
#
# File ~\anaconda3\envs\jcpt\lib\site-packages\bs4\element.py:2289, in ResultSet.__getattr__(self, key)
#    2287 def __getattr__(self, key):
#    2288     """Raise a helpful exception to explain a common code fix."""
# -> 2289     raise AttributeError(
#    2290         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291     )
#
# AttributeError: ResultSet object has no attribute 'split'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
